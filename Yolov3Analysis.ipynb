# %% [markdown]
# <a href="https://colab.research.google.com/github/ashokmuruga/AIMLDL/blob/master/Yolov3Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
im = cv2.imread('ls2.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
im = cv2.imread('car.jpg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
# !pip3 install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 4.1MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.2-cp36-none-any.whl size=10043361 sha256=870b0007e92db159ed5e2cb942792c974514734865ede42f2a86ac788afbb69c
#   Stored in directory: /root/.cache/pip/wheels/22/b7/0f/8d3ee1bf6f30d408e11250bd4d0a8270ffe22fb7b54a987380
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12073 sha256=2868e2c899dbb898681d9cd56629e7b7a6639818f114f6fba38235701ca1d6a3
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...
